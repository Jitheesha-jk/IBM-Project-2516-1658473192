# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn as sk

# %% [markdown]
# ## 1. Download the  dataset

# %% [markdown]
# ## 2. Load the dataset

# %%
data=pd.read_csv("Churn_Modelling.csv")
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# # 3. perform below visualization

# %% [markdown]
# ## univariate analysis Bi- variate analysis, Multi-varaiate  analysis

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.distplot(data.Age)
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Density'>

# %%
sns.displot(data.Age,kind='kde')

# %%
sns.scatterplot(x=data.CustomerId,y=data.RowNumber)
# Out:
# <AxesSubplot: xlabel='CustomerId', ylabel='RowNumber'>

# %%
sns.jointplot(x=data.Age,y=data.Tenure)

# %%
sns.boxplot(data.Age)
# Out:
# <AxesSubplot: >

# %%
sns.barplot(x=data.Age,y=data.Tenure)
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Tenure'>

# %% [markdown]
# # 4. Perform descriptive statistics on the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
data.shape
# Out:
# (10000, 14)

# %%
data.mean()
# Out:
# RowNumber          5.000500e+03
# CustomerId         1.569094e+07
# CreditScore        6.505288e+02
# Age                3.892180e+01
# Tenure             5.012800e+00
# Balance            7.648589e+04
# NumOfProducts      1.530200e+00
# HasCrCard          7.055000e-01
# IsActiveMember     5.151000e-01
# EstimatedSalary    1.000902e+05
# Exited             2.037000e-01
# dtype: float64

# %%
data.median()
# Out:
# RowNumber          5.000500e+03
# CustomerId         1.569074e+07
# CreditScore        6.520000e+02
# Age                3.700000e+01
# Tenure             5.000000e+00
# Balance            9.719854e+04
# NumOfProducts      1.000000e+00
# HasCrCard          1.000000e+00
# IsActiveMember     1.000000e+00
# EstimatedSalary    1.001939e+05
# Exited             0.000000e+00
# dtype: float64

# %%
data.mode()
# Out:
#       RowNumber  CustomerId Surname  CreditScore Geography Gender   Age  \
# 0             1    15565701   Smith        850.0    France   Male  37.0
# 1             2    15565706     NaN          NaN       NaN    NaN   NaN
# 2             3    15565714     NaN          NaN       NaN    NaN   NaN
# 3             4    15565779     NaN          NaN       NaN    NaN   NaN
# 4             5    15565796     NaN          NaN       NaN    NaN   NaN
# ...         ...         ...     ...          ...       ...    ...   ...
# 9995       9996    15815628     NaN          NaN       NaN    NaN   NaN
# 9996       9997    15815645     NaN          NaN       NaN    NaN   NaN
# 9997       9998    15815656     NaN          NaN       NaN    NaN   NaN
# 9998       9999    15815660     NaN          NaN       NaN    NaN   NaN
# 9999      10000    15815690     NaN          NaN       NaN    NaN   NaN
#
#       Tenure  Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
data.var()
# Out:
# RowNumber          8.334167e+06
# CustomerId         5.174815e+09
# CreditScore        9.341860e+03
# Age                1.099941e+02
# Tenure             8.364673e+00
# Balance            3.893436e+09
# NumOfProducts      3.383218e-01
# HasCrCard          2.077905e-01
# IsActiveMember     2.497970e-01
# EstimatedSalary    3.307457e+09
# Exited             1.622225e-01
# dtype: float64

# %%
data.std()
# Out:
# RowNumber           2886.895680
# CustomerId         71936.186123
# CreditScore           96.653299
# Age                   10.487806
# Tenure                 2.892174
# Balance            62397.405202
# NumOfProducts          0.581654
# HasCrCard              0.455840
# IsActiveMember         0.499797
# EstimatedSalary    57510.492818
# Exited                 0.402769
# dtype: float64

# %%
data.skew()
# Out:
# RowNumber          0.000000
# CustomerId         0.001149
# CreditScore       -0.071607
# Age                1.011320
# Tenure             0.010991
# Balance           -0.141109
# NumOfProducts      0.745568
# HasCrCard         -0.901812
# IsActiveMember    -0.060437
# EstimatedSalary    0.002085
# Exited             1.471611
# dtype: float64

# %%
data.kurtosis()
# Out:
# RowNumber         -1.200000
# CustomerId        -1.196113
# CreditScore       -0.425726
# Age                1.395347
# Tenure            -1.165225
# Balance           -1.489412
# NumOfProducts      0.582981
# HasCrCard         -1.186973
# IsActiveMember    -1.996747
# EstimatedSalary   -1.181518
# Exited             0.165671
# dtype: float64

# %% [markdown]
# # 5.Handle the missing values

# %%
data.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# # 6.Find the outliers and replace the outliers

# %%
quantile=data['Age'].quantile(q=[0.75,0.25])

quantile
# Out:
# 0.75    44.0
# 0.25    32.0
# Name: Age, dtype: float64

# %%
quantile.iloc[0]
# Out:
# 44.0

# %%
quantile.iloc[1]
# Out:
# 32.0

# %%
IQR=quantile.iloc[0]-quantile.iloc[1]

IQR
# Out:
# 12.0

# %%
upper_extreme=quantile.iloc[0]+(1.5*IQR)

upper_extreme
# Out:
# 62.0

# %%
lower_extreme=quantile.iloc[0]-(1.5*IQR)

lower_extreme
# Out:
# 26.0

# %% [markdown]
# #  Replace the outliers

# %%
data['age'] = np.where(data['age']>87,40,data['age'])
data['Tenure'] = np.where(data['Tenure']>45,31,data['Tenure'])

# %%
sns.boxplot(data['Age'])
# Out:
# <AxesSubplot: >

# %% [markdown]
# # 7.Check the categorical coding and perform encoding

# %%
data.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
#perform encoding

data.head(2)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
#
#    Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2      0.00              1          1               1
# 1       1  83807.86              1          0               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0

# %%
data['Gender'].replace({"female":0,"male":1},inplace=True)

# %%
data.head(2)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
#
#    Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2      0.00              1          1               1
# 1       1  83807.86              1          0               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0

# %% [markdown]
# ##  8.split the data into independent and dependent variables

# %%
#dependent parameter
y = data['Age']

# %%
#independent parameter
x= data.drop(columns=['Age'],axis=1)

# %%
x.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Tenure  \
# 0          1    15634602  Hargrave          619    France  Female       2
# 1          2    15647311      Hill          608     Spain  Female       1
# 2          3    15619304      Onio          502    France  Female       8
# 3          4    15701354      Boni          699    France  Female       1
# 4          5    15737888  Mitchell          850     Spain  Female       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0

# %% [markdown]
# ## 9. Scale the independent variables

# %%
from sklearn.preprocessing import scale

# %%
names = x.columns

# %%
names
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %% [markdown]
# # 10.split the data into train and test

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train.head()
# Out:
#       RowNumber  CustomerId  Surname  CreditScore Geography  Gender  Tenure  \
# 7389       7390    15676909   Mishin          667     Spain  Female       5
# 9275       9276    15749265  Carslaw          427   Germany    Male       1
# 2995       2996    15582492    Moore          535    France  Female       2
# 5316       5317    15780386    Ferri          654     Spain    Male       5
# 356         357    15611759  Simmons          850     Spain  Female       8
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 7389       0.00              2          1               0        163830.64
# 9275   75681.52              1          1               1         57098.00
# 2995  112367.34              1          1               0        185630.76
# 5316  105683.63              1          1               0        173617.09
# 356   126776.30              2          1               1        132298.49
#
#       Exited
# 7389       0
# 9275       0
# 2995       0
# ...

# %%
x_test.head()
# Out:
#       RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Tenure  \
# 9394       9395    15615753  Upchurch          597   Germany  Female       8
# 898         899    15654700   Fallaci          523    France  Female       2
# 2398       2399    15633877  Morrison          706     Spain  Female       8
# 5906       5907    15745623   Worsnop          788    France    Male       4
# 2343       2344    15765902    Gibson          706   Germany    Male       5
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 9394  131101.04              1          1               1        192852.67
# 898   102967.41              1          1               0        128702.10
# 2398   95386.82              1          1               1         75732.25
# 5906  112079.58              1          0               0         89368.59
# 2343  163034.82              2          1               1        135662.17
#
#       Exited
# 9394       0
# 898        1
# ...
